# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict, Annotated
from pydantic import BaseModel, Field
from dotenv import load_dotenv
import operator

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(model='gpt-4o-mini') # Select a model that supports structured outputs

# %%
# Create a schema or rule. Telling the model what structure to follow in output
class EvaluationSchema(BaseModel):

    feedback: str = Field(description="Detailed feedback for the essay.")
    score: int = Field(description="Score out of 10", ge=0, le=10)

# %%
model_with_structured_output = model.with_structured_output(EvaluationSchema)

# %%
essay = """
Role of India in AI

Artificial Intelligence has become a strategic priority for India, shaping economic growth, governance, and national security. India’s AI strategy, led by NITI Aayog’s “AI for All” and the IndiaAI Mission, focuses on using AI to address population-scale challenges in healthcare, agriculture, education, mobility, and public service delivery. India’s strongest advantage is its vast STEM talent pool, which contributes significantly to global AI development while driving domestic research in NLP for Indian languages and large-scale data systems.

The country’s digital public infrastructure—such as Aadhaar, UPI, DigiLocker, and ONDC—provides a unique foundation for deploying AI at national scale. A rapidly expanding startup ecosystem and investments by major Indian enterprises further boost innovation.

However, challenges persist: limited compute capacity, dependence on imported chips, data quality issues, and the need for massive workforce upskilling. Despite these hurdles, India is well-positioned to emerge as a global leader in inclusive, responsible, and scalable AI solutions.
"""

# %%
prompt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10:\n{essay}'
model_with_structured_output.invoke(prompt)
# Out:
# EvaluationSchema(feedback="The essay effectively covers the critical aspects of India's role in artificial intelligence, highlighting both its strengths and challenges. The structure is coherent, with a logical flow from strategy to execution, and the use of specific examples like NITI Aayog and the digital public infrastructure strengthens the argument. The language is formal and appropriate for the topic, demonstrating a good command of vocabulary and sentence structure. However, the essay could benefit from more detailed explanations of certain points, such as the implications of the challenges mentioned and examples of how AI is being used in the stated sectors like healthcare and education. Additionally, providing a more robust conclusion that reflects on the future outlook for India's AI journey would enhance the overall impact.", score=8)

# %% [markdown]
# Now We have a LLM model with us that gives us structured output according to the specified schema.
#
# Now we are ready to create our workflow.

# %%
class UPSCState(TypedDict):
    essay: str
    language_feedback: str
    analysis_feedback: str
    clarity_feedback: str

    overall_feedback: str

    individual_scores: Annotated[list[int], operator.add]
    avg_score: float

# %%
def evaluate_language(state: UPSCState):

    prompt = f"Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10:\n{state['essay']}"
    output = model_with_structured_output.invoke(prompt)

    return {
        'language_feedback': output.feedback,
        'individual_scores': [output.score]
    }

# %%
def evaluate_analysis(state: UPSCState):
    prompt = f"Evaluate the depth of analysis of the following essay and provide a feedback and assign a score out of 10:\n{state['essay']}"
    output = model_with_structured_output.invoke(prompt)

    return {
        'analysis_feedback': output.feedback,
        'individual_scores': [output.score]
    }

# %%
def evaluate_thought(state: UPSCState):
    prompt = f"Evaluate the clarity of thought of the following essay and provide a feedback and assign a score out of 10:\n{state['essay']}"
    output = model_with_structured_output.invoke(prompt)

    return {
        'clarity_feedback': output.feedback,
        'individual_scores': [output.score]
    }

# %%
def final_evaluation(state: UPSCState):

    # Summary Feedback
    prompt = f"Based on the following feedbacks, provide an overall feedback for the essay:\nLanguage Feedback: {state['language_feedback']}\nAnalysis Feedback: {state['analysis_feedback']}\nClarity Feedback: {state['clarity_feedback']}"
    overall_feedback = model.invoke(prompt).content
    
    # Average Score
    avg_score = sum(state['individual_scores']) / len(state['individual_scores'])

    return {
        'overall_feedback': overall_feedback,
        'avg_score': avg_score
    }

# %%
# Registering the state graph
graph = StateGraph(UPSCState)

# Adding Nodes
graph.add_node('evaluate_language', evaluate_language)
graph.add_node('evaluate_analysis', evaluate_analysis)
graph.add_node('evaluate_thought', evaluate_thought)

graph.add_node('final_evaluation', final_evaluation)

# Adding Edges
graph.add_edge(START, 'evaluate_language')
graph.add_edge(START, 'evaluate_analysis')
graph.add_edge(START, 'evaluate_thought')

graph.add_edge('evaluate_language', 'final_evaluation')
graph.add_edge('evaluate_analysis', 'final_evaluation')
graph.add_edge('evaluate_thought', 'final_evaluation')

graph.add_edge('final_evaluation', END)

# Compiling the graph
workflow = graph.compile()

# %%
initial_state: UPSCState = {
    'essay': essay   
}

# %%
final_output = workflow.invoke(initial_state)
#final_state = workflow.invoke(initial_state)

# %%
final_output
# Out:
# {'essay': '\nRole of India in AI\n\nArtificial Intelligence has become a strategic priority for India, shaping economic growth, governance, and national security. India’s AI strategy, led by NITI Aayog’s “AI for All” and the IndiaAI Mission, focuses on using AI to address population-scale challenges in healthcare, agriculture, education, mobility, and public service delivery. India’s strongest advantage is its vast STEM talent pool, which contributes significantly to global AI development while driving domestic research in NLP for Indian languages and large-scale data systems.\n\nThe country’s digital public infrastructure—such as Aadhaar, UPI, DigiLocker, and ONDC—provides a unique foundation for deploying AI at national scale. A rapidly expanding startup ecosystem and investments by major Indian enterprises further boost innovation.\n\nHowever, challenges persist: limited compute capacity, dependence on imported chips, data quality issues, and the need for massive workforce upskilling. Despite these hurdles, India is well-positioned to emerge as a global leader in inclusive, responsible, and scalable AI solutions.\n',
#  'language_feedback': "The essay presents a concise yet insightful overview of India's role in artificial intelligence. The language quality is generally strong, displaying clarity and coherence throughout. Key points are well-articulated, utilizing an appropriate vocabulary for the subject matter. The structure is logical, progressing from India's advantages to infrastructure and challenges, which enhances readability. However, the essay could benefit from a deeper exploration of some concepts—such as specific examples of how AI is impacting the aforementioned sectors—and a more engaging introduction and conclusion to frame the discussion better. Additionally, there are minor grammatical nuances that can be refined for a more polished finish.",
#  'analysis_feedback': "The essay provides a concise overview of India's role in Artificial Intelligence, touching on strategic initiatives, advantages, and challenges. The analysis effectively identifies key programs like the IndiaAI Mission and the supporting digital infrastructure, which is commendable. However, the depth of analysis could be improved in several areas. \n\n1. **Detail and Examples**: While the essay mentions initiatives and challenges, it lacks specific examples or case studies that could illustrate how these programs are implemented or their impact. Including real-world applications or successful projects would enhance understanding and engagement.\n \n2. **Challenges and Countermeasures**: The essay lists challenges India faces, but it could delve deeper into how these challenges can be addressed or are being tackled. For instance, mentioning specific initiatives for workforce upskilling and partnerships with tech companies could provide a more comprehensive view.\n\n3. **Long-term Vision**: It would benefit from discussing India's long-term vision for AI beyond immediate goals, such as implications for international collaboration and competition.\n\n4. **Statistics and Data Points**: Incorporating relevant statistics, such as market size projections or workforce statistics, would add credibility and depth to the arguments made.\n\nOverall, the essay effectively outlines the current landscape of AI in India but lacks the thoroughness and detail required for a more profound analysis.",
#  'clarity_feedback': 'The essay presents a clear and structured overview of India\'s role in AI, outlining both the opportunities and challenges faced by the country in this field. It effectively highlights the strategic initiatives like "AI for All" and the significance of India\'s digital infrastructure. The mention of the STEM talent pool and startup ecosystem adds depth to the analysis, showcasing the strengths India possesses. However, while the essay covers important points, it could improve clarity by expanding on the implications of the challenges mentioned and providing examples of how these might be addressed. Overall, the ideas are coherent but could be made even clearer with more explicit connections between the points.',
#  'overall_feedback': "Overall Feedback:\n\nThe essay provides a solid and structured overview of India's role in artificial intelligence, effectively outlining the nation's strategic initiatives, advantages, and challenges within this rapidly evolving field. The language employed throughout is clear and coherent, making the arguments accessible to readers while also demonstrating a suitable command of vocabulary pertinent to the topic.\n\nStrengths:\n1. **Clarity and Structure**: The logical progression from India's advantages in AI to its infrastructure and challenges enhances the readability of the essay. The organization aids in guiding the reader through complex concepts without confusion.\n2. **Key Initiatives**: Mentioning notable programs such as the IndiaAI Mission and the focus on enhancing digital infrastructure establishes a foundation for understanding India's strategic approach to AI development.\n3. **Recognition of Talent and Ecosystems**: The inclusion of India's STEM talent pool and burgeoning startup ecosystem adds richness to the analysis, highlighting the intrinsic strengths that the country possesses in the AI landscape.\n\nAreas for Improvement:\n1. **Depth of Analysis**: While the essay identifies key points and initiatives, it would benefit from a more in-depth exploration of these concepts. Including specific examples or case studies to illustrate the real-world applications and impacts of the AI programs mentioned would enhance engagement and comprehension.\n  \n2. **Addressing Challenges**: The essay acknowledges the challenges facing India in the AI domain but does not sufficiently discuss potential solutions or current efforts to mitigate these challenges. Expanding on workforce upskilling initiatives or partnerships with technology firms would provide a more comprehensive view.\n\n3. **Long-Term Vision**: A discussion of India's long-term vision for AI, including potential implications for international collaborations and competition, would help contextualize the current initiatives in a broader perspective.\n\n4. **Utilizing Data**: Incorporating statistics or data points to underscore the arguments made would lend credibility to the analysis. Relevant market size projections or workforce statistics could strengthen the overall discussion.\n\n5. **Engaging Introduction and Conclusion**: The introduction and conclusion could be more impactful. Crafting a compelling opening statement that captures the reader's interest, as well as a stronger closing that reiterates the key takeaways, would frame the discussion more effectively.\n\nIn summary, while the essay effectively outlines the current landscape of AI in India and touches on important elements, enhancing the depth and thoroughness of analysis through examples, elaboration on challenges, and a clearer vision for the future would elevate the overall quality. Refining minor grammatical nuances will also contribute to a more polished final product.",
#  'individual_scores': [7, 7, 7],
#  'avg_score': 7.0}
