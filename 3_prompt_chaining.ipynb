# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()  # take environment variables from .env file
# Out:
# True

# %%
model = ChatOpenAI()

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    # fetch title
    title = state['title']

    # Call llm gen outline
    prompt = f'Create a detailed outline for a blog post on a topic - "{title}"'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline
    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f"Write a comprehensive blog post on the title '{title}' using the following outline:\n{outline}"

    content = model.invoke(prompt).content

    state['content'] = content
    return state

# %%
# Creating the graph or registering the graph
graph = StateGraph(BlogState)

# Adding nodes to the graph
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# Add Edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

# compiling the graph
workflow = graph.compile()

# %%
# Initial State
initial_state = {'title': 'Rise of AI in India'}
final_state = workflow.invoke(initial_state)

# %%
print(final_state['outline'])
# Out:
# I. Introduction
#     A. Explanation of AI (Artificial Intelligence)
#     B. Growing relevance of AI in India
#     C. Purpose of the blog post
#
# II. Overview of AI in India
#     A. Current state of AI in India
#     B. Adoption of AI technologies in various sectors
#     C. Major players in the AI industry in India
#
# III. Factors driving the rise of AI in India
#     A. Government initiatives and policies
#     B. Increased access to technology and data
#     C. Rising demand for automation and efficiency
#     D. Technological advancements in AI research
#
# IV. Impact of AI growth in India
#     A. Job creation and skill development
#     B. Economic growth and competitiveness
#     C. Challenges and potential risks associated with AI development
#     D. Ethical considerations in AI adoption
#
# V. Case studies of AI applications in India
#     A. Healthcare
#     B. Agriculture
#     C. Finance
#     D. Manufacturing
#
# VI. Future outlook of AI in India
#     A. Potential growth opportunities
#     B. Challenges and barriers to AI adoption
#     C. Role of education and training in preparing for AI future
#     D. Importance of ethical AI development
#
# VII. Conclusion
#     A. Recap of key points discussed in the blog post
#     B. Call to action for readers to stay informed and involved in AI developments in India
#     C. Closing thoughts on the significance of embracing AI technology for the future of India.

# %%
print(final_state['content'])
# Out:
# I. Introduction
#
# A. Explanation of AI (Artificial Intelligence)
# Artificial Intelligence (AI) refers to the simulation of human intelligence processes by machines, including learning, reasoning, and self-correction. AI technologies have the ability to analyze vast amounts of data, make decisions, and perform tasks that typically require human intelligence.
#
# B. Growing relevance of AI in India
# In recent years, AI has emerged as a transformative technology with widespread applications across various sectors. India, as a rapidly developing country, is witnessing a surge in the adoption of AI technologies in industries such as healthcare, agriculture, finance, and manufacturing.
#
# C. Purpose of the blog post
# This blog post aims to provide an overview of the rise of AI in India, explore the factors driving its growth, analyze the impact of AI development on the Indian economy, and highlight key case studies of AI applications in different sectors. Additionally, we will look at the future outlook of AI in India and discuss the challenges and opportunities that lie ahead.
#
# II. Overview of AI in India
#
# A. Current state of AI in India
# India is emerging as a key player in the global AI ecosystem, with a growing number of startups, research institutions, and multinational companies investing in AI research and development. The country has been making significant strides in AI innovation and is poised to become a major hub for AI technology.
#
# B. Adoption of AI technologies in various sectors
# AI is being increasingly integrated into various sectors in India, such as healthcare, agriculture, finance, and manufacturing, to improve efficiency, productivity, and decision-making. From personalized healthcare solutions to automated crop management systems, AI is revolutionizing the way businesses operate in the country.
#
# C. Major players in the AI industry in India
# Several Indian companies and research institutions have been at the forefront of AI innovation, including Tata Consultancy Services (TCS), Infosys, Wipro, and the Indian Institutes of Technology (IITs). These organizations are driving AI research, development, and implementation in India and contributing to the country's growing AI ecosystem.
#
# III. Factors driving the rise of AI in India
#
# A. Government initiatives and policies
# The Indian government has been actively promoting AI research and development through initiatives such as the National Artificial Intelligence Portal and the National Strategy for Artificial Intelligence. These efforts are aimed at fostering a conducive environment for AI innovation and attracting investments in the sector.
#
# B. Increased access to technology and data
# The proliferation of smartphones, internet connectivity, and digital platforms has led to a massive influx of data in India. This data reservoir is fueling AI applications that rely on advanced analytics, machine learning, and deep learning algorithms to extract valuable insights and drive decision-making.
#
# C. Rising demand for automation and efficiency
# Indian businesses are increasingly turning to AI technologies to automate routine tasks, enhance operational efficiency, and drive business growth. From chatbots and virtual assistants to predictive analytics and robotic process automation, AI is empowering organizations to streamline processes and improve customer experiences.
#
# D. Technological advancements in AI research
# Advancements in AI research, such as natural language processing, computer vision, and reinforcement learning, have significantly enhanced the capabilities of AI systems. These breakthroughs are enabling Indian developers and organizations to create innovative AI solutions that address complex challenges and deliver tangible outcomes.
#
# IV. Impact of AI growth in India
#
# A. Job creation and skill development
# The rise of AI in India is expected to create new job opportunities in AI development, data science, machine learning, and related fields. However, this growth also necessitates upskilling the workforce to adapt to the evolving job market and meet the demands of the AI-driven economy.
#
# B. Economic growth and competitiveness
# AI has the potential to drive economic growth, improve productivity, and enhance competitiveness in India. By leveraging AI technologies to innovate, optimize processes, and deliver value-added services, businesses can gain a competitive edge in the global market and contribute to the country's economic prosperity.
#
# C. Challenges and potential risks associated with AI development
# The rapid growth of AI in India also poses challenges such as data privacy, cybersecurity, algorithmic bias, and ethical considerations. As AI becomes more pervasive in society, it is crucial to address these challenges proactively and ensure that AI technologies are developed and deployed responsibly.
#
# D. Ethical considerations in AI adoption
# Ethical considerations, such as fairness, transparency, accountability, and bias mitigation, are paramount in AI development and deployment. As AI systems make increasingly consequential decisions that impact individuals and society, it is imperative to uphold ethical standards and ensure that AI technologies serve the common good.
#
# V. Case studies of AI applications in India
#
# A. Healthcare
# AI is being used in healthcare in India to improve diagnostics, treatment planning, patient monitoring, and drug discovery. From AI-powered medical imaging tools to predictive analytics for disease prevention, AI is revolutionizing the healthcare sector and enhancing patient outcomes.
#
# B. Agriculture
# In agriculture, AI technologies are being applied to optimize crop management, monitor soil health, predict crop yields, and mitigate climate risks. AI-driven solutions such as precision agriculture, drone-enabled monitoring, and smart irrigation systems are helping Indian farmers increase productivity and sustainability.
#
# C. Finance
# AI is transforming the financial services industry in India by enabling personalized banking services, fraud detection, risk assessment, and algorithmic trading. AI-powered chatbots, robo-advisors, and credit scoring models are enhancing the customer experience and driving financial inclusion in the country.
#
# D. Manufacturing
# AI is reshaping the manufacturing sector in India by enabling predictive maintenance, quality control, supply chain optimization, and smart manufacturing processes. AI-powered robotics, digital twins, and automated production systems are driving operational efficiency and innovation in Indian factories.
#
# VI. Future outlook of AI in India
#
# A. Potential growth opportunities
# The future of AI in India holds immense growth opportunities across diverse sectors, including healthcare, agriculture, finance, manufacturing, education, and governance. By harnessing the power of AI technologies, India can address societal challenges, drive innovation, and achieve sustainable development goals.
#
# B. Challenges and barriers to AI adoption
# Despite the promising outlook, there are challenges to the widespread adoption of AI in India, such as data privacy concerns, regulatory barriers, talent shortages, and infrastructure limitations. Addressing these challenges requires collaborative efforts from stakeholders in the public and private sectors to build a robust AI ecosystem.
#
# C. Role of education and training in preparing for AI future
# Education and training play a critical role in preparing the Indian workforce for the AI-driven future. By promoting STEM education, digital literacy, and specialized AI skills development, India can cultivate a pool of talent equipped to leverage AI technologies and drive innovation across industries.
#
# D. Importance of ethical AI development
# As AI technologies continue to evolve and impact society, it is essential to prioritize ethical considerations in AI development. Establishing ethical guidelines, standards, and regulatory frameworks can ensure that AI systems are designed and deployed responsibly, safeguarding human rights and promoting inclusivity.
#
# VII. Conclusion
#
# A. Recap of key points discussed in the blog post
# In conclusion, the rise of AI in India is reshaping industries, driving economic growth, and fostering innovation in the country. With advancements in AI research, increased adoption of AI technologies, and a supportive policy environment, India is well-positioned to harness the full potential of AI for the benefit of its people and economy.
#
# B. Call to action for readers to stay informed and involved in AI developments in India
# As AI continues to play a pivotal role in India's development journey, it is crucial for individuals, businesses, policymakers, and researchers to stay informed, engaged, and ethical in their approach to AI adoption. By actively participating in AI initiatives and discussions, we can collectively shape a future where AI technologies serve the common good.
#
# C. Closing thoughts on the significance of embracing AI technology for the future of India
# Embracing AI technology presents India with a transformative opportunity to accelerate growth, enhance competitiveness, and address societal challenges. By fostering a culture of innovation, collaboration, and responsible AI development, India can leverage AI as a catalyst for sustainable development and inclusive progress in the digital age.
